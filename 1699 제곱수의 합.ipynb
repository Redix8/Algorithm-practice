# %%
n = int(input())
dp = [i for i in range(n+1)]
for i in range(2,n+1):
    for j in range(2,i):
        if j*j>i: break
        if dp[i]> dp[i-j*j]+1:
            dp[i] = dp[i-j*j]+1
print(dp[n])
# Out:
# 100000
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# 301
# ...

# %%
dp
# Out:
# [0, 1, 2, 3, -1, 0, 1, 2]
